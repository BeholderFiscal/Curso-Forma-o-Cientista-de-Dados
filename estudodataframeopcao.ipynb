# %%
import pandas as pd
import numpy as np

# Carregamento de dados

dados = pd.read_excel('dataframe.xlsx')
display(dados.head())
# Out:
#                                            Emitente       Emitente CNPJ  \
# 0                   PNEUBRAS COMERCIO DE PNEUS LTDA  08.678.386/0059-13
# 1  PMP DIST. DE ACESSORIOS E IMP. DE MOTOPECAS LTDA  34.790.793/0001-01
# 2  PMP DIST. DE ACESSORIOS E IMP. DE MOTOPECAS LTDA  34.790.793/0001-01
# 3               BRASIL COMPONENTES AUTOMOTIVOS LTDA  11.031.766/0010-40
# 4               BRASIL COMPONENTES AUTOMOTIVOS LTDA  11.031.766/0010-40
#
#                             Destinatário   Destinatário CNPJ  Número  \
# 0                       J E V PNEUS LTDA  40.866.840/0001-56    3331
# 1  ALEXANDRE VIEIRA DA SILVA 12312109409  35.820.846/0001-52  126769
# 2            JOSE DONATO DA SILVA JUNIOR  35.795.916/0001-60  126772
# 3              ELIEVALTER FERRAO MOREIRA  12.299.252/0001-42    3329
# 4            GABRIEL ARCOVERDE DE MORAES  05.524.717/0001-56    3328
#
#                                 Chave de Acesso    Valor     Emissão  Volumes  \
# ...

# %%
dados.describe()
# Out:
#              Número         Valor      Volumes  Valor do Frete   CT-e Valor  \
# count  6.066000e+03   6066.000000  5665.000000     6066.000000  2944.000000
# mean   4.457754e+05   1873.574649     4.813239        3.477165    46.477208
# std    5.360307e+05   2638.283092    16.739595       10.591267    63.097935
# min    1.000000e+00      2.640000     1.000000        0.000000     0.090000
# 25%    5.273050e+04    525.000000     1.000000        0.000000    21.827500
# 50%    1.387905e+05   1210.000000     2.000000        0.000000    30.560000
# 75%    7.944485e+05   2263.607500     5.000000        0.000000    50.360000
# max    1.683178e+06  76900.000000   752.000000      156.490000  1599.520000
#
#              Série          Peso
# count  6066.000000   4766.000000
# mean      9.167656     51.452016
# std      31.998373    507.859360
# min       0.000000      0.001000
# 25%       1.000000      4.570750
# 50%       1.000000     12.361000
# 75%       1.000000     40.000000
# ...

# %%
autonorte = dados.loc[dados['Emitente CNPJ'] == '11.509.676/0005-55']
autonorte = autonorte.loc[autonorte['Emissão'] == '01/02/2024']
display(autonorte[['Destinatário', 'CT-e Número']])
# Out:
#                                            Destinatário CT-e Número
# 52                         PRIME PECAS AUTOMOTIVAS LTDA      910099
# 58                                     CARUARU BUS LTDA      910153
# 74                               SERGIO TEODORO DIAS ME      910184
# 76                   JC SILVA SERVICOS AUTOMOTIVOS LTDA      910144
# 77               JEFFERSON BARBOSA DA SILVA 07765317431      910183
# ...                                                 ...         ...
# 2918            ALIZONAITON RAMOS FERREIRA AUTO MOLAS -         NaN
# 2919                        GABRIELI SILVA PEDROZA LTDA         NaN
# 2921                            RICARDO AUTO PECAS LTDA         NaN
# 4502  MIHAYLOV FERREIRA ARAUJO AUTOPECAS E SERVICOS ...         NaN
# 4503                      WILLIAMS JOSE DO PRADO LORENA         NaN
#
# [124 rows x 2 columns]

# %%
autonorte.isnull().sum()
# Out:
# Emitente                    0
# Emitente CNPJ               0
# Destinatário                0
# Destinatário CNPJ           0
# Número                      0
# Chave de Acesso             0
# Valor                       0
# Emissão                     0
# Volumes                     0
# Valor do Frete              0
# Status                      0
# CT-e Número                68
# CT-e Valor                 68
# Emitente Município          0
# Destinatário Município      0
# Transportador CNPJ          0
# Transportador Município     0
# Transportador Endereço      0
# Transportador UF            0
# Situação                    0
# Série                       0
# Peso                        0
# dtype: int64
